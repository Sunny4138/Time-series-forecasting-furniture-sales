# %%
import joblib

# Load the model
loaded_model = joblib.load("sarimax_furniture_model.pkl")

print("Model Loaded Successfully!")
# Out:
# Model Loaded Successfully!

# %%
# Forecast the next 12 months
forecast = loaded_model.get_forecast(steps=12)

# Get predicted values
forecast_values = forecast.predicted_mean
print("Forecasted Values:")
print(forecast_values)
# Out:
# Forecasted Values:
# 2015-01-01    129432.106497
# 2015-02-01    110299.709109
# 2015-03-01    126803.925954
# 2015-04-01    112641.892234
# 2015-05-01    135677.075372
# 2015-06-01    175295.126342
# 2015-07-01    127691.290150
# 2015-08-01    169539.435876
# 2015-09-01    198737.512147
# 2015-10-01    157645.882754
# 2015-11-01    193017.787061
# 2015-12-01    206365.507126
# Freq: MS, Name: predicted_mean, dtype: float64
